# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("advertising.csv")
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.tail()
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]>

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
plt.scatter(x['TV'],y)
plt.xlabel("Radio")
plt.ylabel("Price")
plt.title("TV sales",size=20)
# Out:
# Text(0.5, 1.0, 'TV sales')

# %%
plt.scatter(x['Radio'],y,color='r')
plt.xlabel("Radio")
plt.ylabel("Price")
plt.title("Radio sales",size=20)
# Out:
# Text(0.5, 1.0, 'Radio sales')

# %%
plt.scatter(x['Newspaper'],y,color='g')
plt.xlabel("Radio")
plt.ylabel("Price")
plt.title("Newspaper sales",size=20)
# Out:
# Text(0.5, 1.0, 'Newspaper sales')

# %%
import seaborn as sb
sb.regplot(x=df["TV"],y=y,color='k')
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sb.regplot(x=df['Radio'],y=y,color='r')
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sb.regplot(x=df['Newspaper'],y=y,color='g')
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30)
x_train
# Out:
#         TV  Radio  Newspaper
# 23   228.3   16.9       26.2
# 162  188.4   18.1       25.6
# 191   75.5   10.8        6.0
# 129   59.6   12.0       43.1
# 112  175.7   15.4        2.4
# ..     ...    ...        ...
# 150  280.7   13.9       37.0
# 154  187.8   21.1        9.5
# 192   17.2    4.1       31.6
# 2     17.2   45.9       69.3
# 167  206.8    5.2       19.4
#
# [140 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 51   100.4    9.6        3.6
# 52   216.4   41.7       39.6
# 72    26.8   33.0       19.3
# 27   240.1   16.7       22.9
# 115   75.1   35.0       52.7
# 161   85.7   35.8       49.3
# 145  140.3    1.9        9.0
# 132    8.4   27.2        2.1
# 139  184.9   43.9        1.7
# 15   195.4   47.7       52.9
# 188  286.0   13.9        3.7
# 10    66.1    5.8       24.2
# 199  232.1    8.6        8.7
# 198  283.6   42.0       66.2
# 110  225.8    8.2       56.5
# 97   184.9   21.0       22.0
# 117   76.4    0.8       14.8
# 182   56.2    5.7       29.7
# 56     7.3   28.1       41.4
# 62   239.3   15.5       27.3
# 175  276.9   48.9       41.8
# 164  117.2   14.7        5.4
# 101  296.4   36.3      100.9
# 90   134.3    4.9        9.3
# 29    70.6   16.0       40.8
# 190   39.5   41.1        5.8
# 143  104.6    5.7       34.4
# 124  229.5   32.3       74.2
# 138   43.0   25.9       20.5
# 160  172.5   18.1       30.7
# 104  238.2   34.3        5.3
# ...

# %%
y_train
# Out:
# 23     20.5
# 162    19.9
# 191    11.9
# 129     9.7
# 112    17.1
#        ...
# 150    16.1
# 154    20.6
# 192     5.9
# 2      12.0
# 167    17.2
# Name: Sales, Length: 140, dtype: float64

# %%
y_test
# Out:
# 51     10.7
# 52     22.6
# 72      8.8
# 27     20.9
# 115    12.6
# 161    13.3
# 145    10.3
# 132     5.7
# 139    20.7
# 15     22.4
# 188    20.9
# 10     12.6
# 199    18.4
# 198    25.5
# 110    18.4
# 97     20.5
# 117     9.4
# 182     8.7
# 56      5.5
# 62     20.7
# 175    27.0
# 164    11.9
# 101    23.8
# 90     14.0
# 29     10.5
# 190    10.8
# 143    10.4
# 124    19.7
# 138     9.6
# 160    16.4
# 104    20.7
# 92     19.4
# 113    20.9
# 181    17.2
# 68     18.9
# 196    14.0
# 75      8.7
# 109    19.8
# 174    16.5
# 140    10.9
# 163    18.0
# 119     6.6
# 13     13.7
# 69     22.3
# 79     11.0
# 12      9.2
# 102    19.8
# 149    10.1
# 98     25.4
# 89     16.7
# 7      13.2
# 118    15.9
# 18     11.3
# 34     11.9
# 172     7.6
# 171    17.5
# 91      7.3
# 96     16.7
# 197    14.8
# 43     17.9
# Name: Sales, dtype: float64

# %%
# model creation

from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
print(model.predict([[50,30,55]]))
# Out:
# [10.59966999]
# c:\Users\rohith preethan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("slope =",list(zip(x,model.coef_)))
# Out:
# slope = [('TV', np.float64(0.05360484690328438)), ('Radio', np.float64(0.11040950729804502)), ('Newspaper', np.float64(0.003096642911197961))]

# %%
print("constant=",model.intercept_)
# Out:
# constant= 4.436827066987103

# %%
df1=pd.DataFrame({"Actual Value":y_test,"Predicted Value":y_pred,"Difference":y_test-y_pred})
df1
# Out:
#      Actual Value  Predicted Value  Difference
# 51           10.7        10.889833   -0.189833
# 52           22.6        20.763619    1.836381
# 72            8.8         9.576716   -0.776716
# 27           20.9        19.222103    1.677897
# 115          12.6        12.490077    0.109923
# 161          13.3        13.136087    0.163913
# 145          10.3        12.195235   -1.895235
# 132           5.7         7.896749   -2.196749
# 139          20.7        19.200605    1.499395
# 15           22.4        20.341560    2.058440
# 188          20.9        21.313963   -0.413963
# 10           12.6         8.695421    3.904579
# 199          18.4        17.854975    0.545025
# 198          25.5        24.481359    1.018641
# 110          18.4        17.621120    0.778880
# 97           20.5        16.735089    3.764911
# 117           9.4         8.666395    0.733605
# 182           8.7         8.170724    0.529276
# 56            5.5         8.058851   -2.558851
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,root_mean_squared_error,r2_score
mae=mean_absolute_error(y_test,y_pred)
mape=mean_absolute_percentage_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=root_mean_squared_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
mae
# Out:
# 1.1456553136706171

# %%
mape
# Out:
# 0.08560601257776948

# %%
mse
# Out:
# 2.240297752744468

# %%
rmse
# Out:
# 1.4967624236145387

# %%
score
# Out:
# 0.9245880298110717

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=2)
x_train_poly=poly.fit_transform(x_train)
x_test_poly=poly.fit_transform(x_test)

# %%
model1=LinearRegression()
model1.fit(x_train_poly,y_train)
y_pred1=model1.predict(x_test_poly)

# %%
mape1=mean_absolute_percentage_error(y_test,y_pred1)
score1=r2_score(y_test,y_pred1)
mape1
# Out:
# 0.07358551883113004

# %%
score1
# Out:
# 0.9388801248818622
