# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
df=pd.read_csv("SalaryMulti.csv")
df
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                   7                     2                           4
# 1                   4                     0                           2
# 2                  13                     4                           8
# 3                  11                     3                           2
# 4                   8                     1                           6
# ..                ...                   ...                         ...
# 995                 8                     1                           6
# 996                12                     3                           1
# 997                14                    10                           1
# 998                 7                     5                           0
# 999                10                     6                           2
#
#      Certifications         Salary
# 0                 1   77318.070547
# ...

# %%
df.head()
# Out:
#    Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                 7                     2                           4
# 1                 4                     0                           2
# 2                13                     4                           8
# 3                11                     3                           2
# 4                 8                     1                           6
#
#    Certifications         Salary
# 0               1   77318.070547
# 1               3   64951.950980
# 2               3  106058.185204
# 3               1   89649.944851
# 4               3   82206.019687

# %%
df.tail()
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 995                 8                     1                           6
# 996                12                     3                           1
# 997                14                    10                           1
# 998                 7                     5                           0
# 999                10                     6                           2
#
#      Certifications         Salary
# 995               4   90941.688891
# 996               2   92074.890941
# 997               2  115914.944924
# 998               2   82706.285700
# 999               4   85347.167601

# %%
df.columns
# Out:
# Index(['Total Experience', 'Team Lead Experience',
#        'Project Manager Experience', 'Certifications', 'Salary'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Total Experience                int64
# Team Lead Experience            int64
# Project Manager Experience      int64
# Certifications                  int64
# Salary                        float64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of      Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                   7                     2                           4
# 1                   4                     0                           2
# 2                  13                     4                           8
# 3                  11                     3                           2
# 4                   8                     1                           6
# ..                ...                   ...                         ...
# 995                 8                     1                           6
# 996                12                     3                           1
# 997                14                    10                           1
# 998                 7                     5                           0
# 999                10                     6                           2
#
#      Certifications         Salary
# 0                 1   77318.070547
# ...

# %%
df.isna().sum()
# Out:
# Total Experience              0
# Team Lead Experience          0
# Project Manager Experience    0
# Certifications                0
# Salary                        0
# dtype: int64

# %%
x=df.iloc[:,:-1]
x
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 0                   7                     2                           4
# 1                   4                     0                           2
# 2                  13                     4                           8
# 3                  11                     3                           2
# 4                   8                     1                           6
# ..                ...                   ...                         ...
# 995                 8                     1                           6
# 996                12                     3                           1
# 997                14                    10                           1
# 998                 7                     5                           0
# 999                10                     6                           2
#
#      Certifications
# 0                 1
# 1                 3
# 2                 3
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       77318.070547
# 1       64951.950980
# 2      106058.185204
# 3       89649.944851
# 4       82206.019687
#            ...
# 995     90941.688891
# 996     92074.890941
# 997    115914.944924
# 998     82706.285700
# 999     85347.167601
# Name: Salary, Length: 1000, dtype: float64

# %%
plt.scatter(x["Total Experience"],y,color='k')
plt.xlabel("Total xperience")
plt.ylabel("Salary")
plt.title("Total Experience - Salary",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Total Experience - Salary')

# %%
plt.scatter(x["Team Lead Experience"],y,color='k')
plt.xlabel("Team Lead Experience")
plt.ylabel("Salary")
plt.title("Team Lead Experience - Salary",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Team Lead Experience - Salary')

# %%
plt.scatter(x["Project Manager Experience"],y,color='k')
plt.xlabel("Project Manager Experience")
plt.ylabel("Salary")
plt.title("Project Manager Experience - Salary",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Project Manager Experience - Salary')

# %%
plt.scatter(x["Certifications"],y,color='k')
plt.xlabel("Certification")
plt.ylabel("Salary")
plt.title("Certificatiom",fontsize=25)
# Out:
# Text(0.5, 1.0, 'Certificatiom')

# %%
sb.regplot(x=df["Total Experience"],y=y,color='r')
# Out:
# <Axes: xlabel='Total Experience', ylabel='Salary'>

# %%
sb.regplot(x=df["Team Lead Experience"],y=y,color='b')
# Out:
# <Axes: xlabel='Team Lead Experience', ylabel='Salary'>

# %%
sb.regplot(x=df["Project Manager Experience"],y=y,color='g')
# Out:
# <Axes: xlabel='Project Manager Experience', ylabel='Salary'>

# %%
sb.regplot(x=df["Certifications"],y=y,color='c')
# Out:
# <Axes: xlabel='Certifications', ylabel='Salary'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)
x_train
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 105                 5                     1                           2
# 68                  4                     0                           2
# 479                 4                     2                           0
# 399                 6                     5                           0
# 434                12                     5                           5
# ..                ...                   ...                         ...
# 835                 4                     1                           1
# 192                11                     3                           4
# 629                12                     3                           0
# 559                 5                     2                           1
# 684                 8                     1                           5
#
#      Certifications
# 105               4
# 68                2
# 479               3
# ...

# %%
x_test
# Out:
#      Total Experience  Team Lead Experience  Project Manager Experience  \
# 993                 6                     4                           1
# 859                12                     0                           2
# 298                 4                     2                           1
# 553                 2                     0                           0
# 672                 4                     2                           0
# ..                ...                   ...                         ...
# 167                 7                     3                           0
# 998                 7                     5                           0
# 984                 2                     1                           0
# 491                 2                     0                           0
# 10                  7                     1                           1
#
#      Certifications
# 993               4
# 859               4
# 298               3
# ...

# %%
y_train
# Out:
# 105     66590.626744
# 68      64725.529997
# 479     64758.563518
# 399     84394.290254
# 434     97541.495619
#            ...
# 835     72707.379578
# 192     90747.315753
# 629    107426.295013
# 559     67340.888959
# 684     88320.886194
# Name: Salary, Length: 700, dtype: float64

# %%
y_test
# Out:
# 993    76501.349119
# 859    97865.098626
# 298    60509.378241
# 553    58317.436077
# 672    61523.268388
#            ...
# 167    78467.949557
# 998    82706.285700
# 984    53317.468126
# 491    56256.738242
# 10     79865.623188
# Name: Salary, Length: 300, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
print(model.predict([[8,5,2,1]]))
# Out:
# [86460.57407815]
# c:\Users\rohith preethan\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("Slope =",list(zip(x,model.coef_)))
# Out:
# Slope = [('Total Experience', np.float64(2959.625700425037)), ('Team Lead Experience', np.float64(1943.2964942366357)), ('Project Manager Experience', np.float64(1099.2824921397475)), ('Certifications', np.float64(359.6606912096874))]

# %%
print("Constant =",model.intercept_)
# Out:
# Constant = 50508.86032807529

# %%
df1=pd.DataFrame({"Actual Value":y_test,"Predicted Value":y_pred,"Difference":y_test-y_pred})
df1
# Out:
#      Actual Value  Predicted Value   Difference
# 993  76501.349119     78577.725765 -2076.376645
# 859  97865.098626     89661.576482  8203.522144
# 298  60509.378241     68412.220684 -7902.842443
# 553  58317.436077     57147.433111  1170.002965
# 672  61523.268388     66233.956118 -4710.687730
# ..            ...              ...          ...
# 167  78467.949557     77415.790405  1052.159152
# 998  82706.285700     81662.044085  1044.241616
# 984  53317.468126     58371.408223 -5053.940097
# 491  56256.738242     56787.772420  -531.034178
# 10   79865.623188     74268.819217  5596.803971
#
# [300 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,root_mean_squared_error,r2_score
mae=mean_absolute_error(y_test,y_pred)
mape=mean_absolute_percentage_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
rmse=root_mean_squared_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
mae
# Out:
# 4121.082019132123

# %%
mape
# Out:
# 0.05442159363661582

# %%
mse
# Out:
# 26809389.60495267

# %%
rmse
# Out:
# 5177.778443015177

# %%
score
# Out:
# 0.9190800706504667
